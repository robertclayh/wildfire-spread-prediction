# %% [markdown]
# <a href="https://colab.research.google.com/github/robertclayh/wildfire-spread-prediction/blob/main/Qualitivecomparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python eval_qualitative_cases.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Device: cuda
# Reusing NPZ tiles from pipeline at: /scratch/root/wildfire_npz_tiles_mndws_v1
# Device: cuda
# Channels configured (21): ['prev_fire', 'u', 'v', 'temp', 'rh', 'ndvi', 'slope', 'aspect', 'barrier', 'erc', 'pdsi', 'pr', 'bi', 'chili', 'fuel1', 'fuel2', 'fuel3', 'impervious', 'water', 'wind_75', 'gust_med']
# Channel stats computed -> torch.Size([21]) torch.Size([21])
# ...

# %%
from IPython.display import Image, display

display(Image("figs_qualitative/fig6a_simple_success.png"))
display(Image("figs_qualitative/fig6b_lr_fail_unet_success.png"))
display(Image("figs_qualitative/fig6c_shared_failure.png"))
